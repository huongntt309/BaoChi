# %% [markdown]
# ## 1. Importing the required libraries

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Loading the data into the data frame.

# %%
df = pd.read_csv("/content/TNMT_noidung_tinbai.csv", encoding = 'utf-8')
# To display the top 5 rows
df.head(5)
# Out:
#      Thoigian        Linh_vuc           Chuyen_muc  \
# 0  11/12/2023  biển - hải đảo  chính sách, quản lý
# 1   5/12/2023  biển - hải đảo     kiến nghị, xử lý
# 2  15/12/2023  biển - hải đảo  chính sách, quản lý
# 3  25/12/2023  biển - hải đảo  chính sách, quản lý
# 4   6/12/2023  biển - hải đảo  chính sách, quản lý
#
#                             Dia_diem  Muc_do  \
# 0                           Bộ TN&MT       4
# 1  Quảng Ninh, Khánh Hòa, Ninh Thuận       2
# 2                          toàn quốc       4
# 3                          toàn quốc       4
# 4                          toàn quốc       4
#
#                                            Nguon_tin  \
# 0  Dân Việt, Tuổi trẻ, Công lý, Môi trường & Đô t...
# 1                                        Quảng Ninh
# 2                                        VietNamPlus
# 3                                           Nhân Dân
# 4                                              TN&MT
#
#                                              Tin_bai  \
# 0  Làm rõ dự án đô thị lấn biển vùng đệm vịnh Hạ ...
# 1        Nghề nuôi biển: Nhiều rào cản phải tháo gỡ.
# 2  Hạch toán tài khoản đại dương: Cơ hội để phát ...
# 3  Xây dựng kế hoạch giảm thiểu khai thác không c...
# 4  Thúc đẩy nghiên cứu khoa học, công nghệ biển t...
#
#                                         Link_tin_bai  \
# 0  https://danviet.vn/du-an-do-thi-lan-bien-vung-...
# 1  https://vneconomy.vn/nghe-nuoi-bien-nhieu-rao-...
# 2  https://www.vietnamplus.vn/hach-toan-tai-khoan...
# 3  https://nhandan.vn/xay-dung-ke-hoach-giam-thie...
# 4  https://baotainguyenmoitruong.vn/thuc-day-nghi...
#
#                                     Tom_tat_noi_dung  Muc_do_ten  \
# 0  sau khi kiểm tra "dự án đô thị lấn biển vùng đ...  Trung tính
# 1  tại nhiều địa phương người dân nuôi trồng hải ...    Tiêu cực
# 2  để thực hiện hiệu quả mục tiêu của Chiến lược ...  Trung tính
# 3  Ngày 22/12, tại thành phố Hội An (Quảng Nam), ...  Trung tính
# 4  Hội thảo Thúc đẩy nghiên cứu khoa học, công ng...  Trung tính
#
#                                     Noi_dung_tin_bai
# 0  Bộ Xây dựng vừa có 2 văn bản gửi Bộ Văn hóa Th...
# 1  Chủ trì Hội nghị Thực trạng cung ứng con giống...
# 2  Để thực hiện hiệu quả mục tiêu của Chiến lược ...
# 3  Hội thảo là một trong những hoạt động nằm Tron...
# 4  Ngày 05 12 tại Hà Nội Cục Biển và Hải đảo Việt...

# %% [markdown]
# ---

# %% [markdown]
# ### Checking the types of data

# %%
df.dtypes
# Out:
# Thoigian            object
# Linh_vuc            object
# Chuyen_muc          object
# Dia_diem            object
# Muc_do               int64
# Nguon_tin           object
# Tin_bai             object
# Link_tin_bai        object
# Tom_tat_noi_dung    object
# Muc_do_ten          object
# Noi_dung_tin_bai    object
# dtype: object

# %% [markdown]
# ### Dropping the duplicate rows

# %%
df.shape
# Out:
# (977, 11)

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 11)

# %%
# df.drop_duplicates(inplace=True)
# df

# %%
df.count()      # Used to count the number of rows
# Out:
# Thoigian            977
# Linh_vuc            977
# Chuyen_muc          977
# Dia_diem            977
# Muc_do              977
# Nguon_tin           977
# Tin_bai             977
# Link_tin_bai        977
# Tom_tat_noi_dung    977
# Muc_do_ten          977
# Noi_dung_tin_bai    954
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ### Dropping the missing or null values.

# %%
print(df.isnull().sum())
df = df.dropna()    # Dropping the missing values.
df.count()
# Out:
# Thoigian             0
# Linh_vuc             0
# Chuyen_muc           0
# Dia_diem             0
# Muc_do               0
# Nguon_tin            0
# Tin_bai              0
# Link_tin_bai         0
# Tom_tat_noi_dung     0
# Muc_do_ten           0
# Noi_dung_tin_bai    23
# dtype: int64
# Thoigian            954
# Linh_vuc            954
# Chuyen_muc          954
# Dia_diem            954
# Muc_do              954
# Nguon_tin           954
# Tin_bai             954
# Link_tin_bai        954
# Tom_tat_noi_dung    954
# Muc_do_ten          954
# Noi_dung_tin_bai    954
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ### Pre-process Linh_vuc and Chuyen_muc, Muc do, Link

# %%
# Thay thế các nhãn trùng lặp trong cột 'Linh_vuc'
df['Linh_vuc'].replace('KTTV -BĐKH', 'KTTV-BĐKH', inplace=True)
df['Linh_vuc'].replace('KTTV - BĐKH', 'KTTV-BĐKH', inplace=True)
df['Linh_vuc'].replace('KTTV-BĐKH', 'Khí tượng thủy văn - Biến đổi khí hậu', inplace=True)

# %%
# import re
# df['Chuyen_muc'] = df['Chuyen_muc'].apply(lambda x: re.sub(r'\s+', ' ', x.strip()) if 'thông tin khác' in x else x)

# %%
# Ánh xạ các giá trị của cột 'Muc_do' sử dụng từ điển
# mapping = {1: "Rất tiêu cực", 2: "Tiêu cực", 3: "Tích cực", 4: "Trung tính"}
# df['Muc_do_ten'] = df['Muc_do'].map(mapping)

# %%
def remove_links_from_column(df, column_name, links_to_remove):
    """
    Remove links from a specific column in a DataFrame.

    Args:
    - df (DataFrame): The DataFrame to remove links from.
    - column_name (str): The name of the column to check for links.
    - links_to_remove (list): A list of links to be removed from the DataFrame.

    Returns:
    - DataFrame: The DataFrame with the specified links removed.
    """
    # Iterate through each link to remove
    for link in links_to_remove:
        # Check if the link is present in any cell of the specified column
        mask = df[column_name].str.contains(link)
        # Remove rows where the link is present in the specified column
        df = df[~mask]

    return df

# List of links to be removed
links_to_remove = [
    # các link quá ít báo
    "antt.vn",
    "dangcongsan.vn",
    "dttc.sggp.org.vn",
    "kinhtemoitruong.vn",
    "lifestyle.zingnews.vn",
    "phunuvietnam.vn",
    "quochoitv.vn",
    "thanglong.chinhphu.vn",
    "www.phapluatplus.vn",
    "quanly.moitruongvadothi.vn",
    "amp.vtc.vn",
    "baohaiduong.vn",
    "baonghean.vn",
    "baotayninh.vn",
    "baovephapluat.vn",
    "bnews.vn",
    "cafef.vn",
    "daklak24h.com.vn",
    "etv.quochoi.vn",
    "giaoduc.net.vn",
    "hcmcpv.org.vn",
    "meeyland.com",
    "nangluongvietnam.vn",
    "news.baodansinh.vn",
    "petrotimes.vn",
    "taichinhdoanhnghiep.net.vn",
    "theleader.vn",
    "thethaovanhoa.vn",
    "thoibaotaichinhvietnam.vn",
    "tintucvietnam.vn",
    "vovgiaothong.vn",
    "www.doisongphapluat.com",
    "www.youtube.com",

    # 3 link đang lỗi 1 link quốc hội k cho quét
    "nongnghiep.vn",
    "baotintuc.vn",
    "vietnamnet.vn"
    "quochoi.vn"
    "Downloads"
]

# Name of the column to check for links
column_name = 'Link_tin_bai'  # Replace 'Your_Column_Name' with the actual column name

# Call the function to remove links from the specified column directly in the original DataFrame
df_cleaned = remove_links_from_column(df, column_name, links_to_remove)

# %%
df_cleaned = df_cleaned.reset_index(drop=True)
df_cleaned
# Out:
#        Thoigian         Linh_vuc           Chuyen_muc  \
# 0    11/12/2023   biển - hải đảo  chính sách, quản lý
# 1     5/12/2023   biển - hải đảo     kiến nghị, xử lý
# 2    15/12/2023   biển - hải đảo  chính sách, quản lý
# 3    25/12/2023   biển - hải đảo  chính sách, quản lý
# 4     6/12/2023   biển - hải đảo  chính sách, quản lý
# ..          ...              ...                  ...
# 949   4/12/2023  thông tin chung       thông tin khác
# 950   5/12/2023  thông tin chung       thông tin khác
# 951   4/12/2023  thông tin chung       thông tin khác
# 952   4/12/2023  thông tin chung       thông tin khác
# 953   6/12/2023  thông tin chung       thông tin khác
#
#                               Dia_diem  Muc_do  \
# 0                             Bộ TN&MT       4
# 1    Quảng Ninh, Khánh Hòa, Ninh Thuận       2
# 2                            toàn quốc       4
# 3                            toàn quốc       4
# 4                            toàn quốc       4
# ..                                 ...     ...
# 949                          toàn quốc       4
# 950                          toàn quốc       4
# 951                          toàn quốc       4
# 952                          toàn quốc       4
# 953                          toàn quốc       4
#
#                                              Nguon_tin  \
# 0    Dân Việt, Tuổi trẻ, Công lý, Môi trường & Đô t...
# 1                                          Quảng Ninh
# 2                                          VietNamPlus
# 3                                             Nhân Dân
# 4                                                TN&MT
# ..                                                 ...
# 949                                         (VnExpress
# 950                                            VnMedia
# 951                                          VietNamNe
# 952                                           VOV, VTV
# 953           Kinh tế & Đô thị, Diễn đàn doanh nghiệp
#
#                                                Tin_bai  \
# 0    Làm rõ dự án đô thị lấn biển vùng đệm vịnh Hạ ...
# 1          Nghề nuôi biển: Nhiều rào cản phải tháo gỡ.
# 2    Hạch toán tài khoản đại dương: Cơ hội để phát ...
# 3    Xây dựng kế hoạch giảm thiểu khai thác không c...
# 4    Thúc đẩy nghiên cứu khoa học, công nghệ biển t...
# ..                                                 ...
# 949  Thủ tướng đề nghị các nước 'nói là làm' trong ...
# 950  Các ngân hàng phát triển đa phương thúc đẩy hà...
# 951  Thủ tướng gửi thông điệp khai thông bế tắc ...
# 952  Thủ tướng dự và phát biểu tại Hội nghị Thượng ...
# 953  Việt Nam, Đan Mạch và những gặt hái hứa hẹn từ...
#
#                                           Link_tin_bai  \
# 0    https://danviet.vn/du-an-do-thi-lan-bien-vung-...
# 1    https://vneconomy.vn/nghe-nuoi-bien-nhieu-rao-...
# 2    https://www.vietnamplus.vn/hach-toan-tai-khoan...
# 3    https://nhandan.vn/xay-dung-ke-hoach-giam-thie...
# 4    https://baotainguyenmoitruong.vn/thuc-day-nghi...
# ..                                                 ...
# 949  https://vnexpress.net/thu-tuong-de-nghi-cac-nu...
# 950  https://vnmedia.vn/kinh-te/202312/cac-ngan-han...
# 951  https://vietnamnet.vn/thu-tuong-gui-thong-diep...
# 952  https://vov.vn/chinh-tri/thu-tuong-du-va-phat-...
# 953  https://kinhtedothi.vn/viet-nam-dan-mach-va-nh...
#
#                                       Tom_tat_noi_dung  Muc_do_ten  \
# 0    sau khi kiểm tra "dự án đô thị lấn biển vùng đ...  Trung tính
# 1    tại nhiều địa phương người dân nuôi trồng hải ...    Tiêu cực
# 2    để thực hiện hiệu quả mục tiêu của Chiến lược ...  Trung tính
# 3    Ngày 22/12, tại thành phố Hội An (Quảng Nam), ...  Trung tính
# 4    Hội thảo Thúc đẩy nghiên cứu khoa học, công ng...  Trung tính
# ..                                                 ...         ...
# 949  Thủ tướng Phạm Minh Chính dẫn đầu đã có nhiều ...  Trung tính
# 950  các ngân hàng phát triển đa phương tái khẳng đ...  Trung tính
# 951  Thủ tướng Phạm Minh Chính dẫn đầu đã có nhiều ...  Trung tính
# 952  Thủ tướng Phạm Minh Chính dẫn đầu đã có nhiều ...  Trung tính
# 953  Việt Nam và Đan Mạch sẽ tiếp tục hợp tác để đạ...  Trung tính
#
#                                       Noi_dung_tin_bai
# 0    Bộ Xây dựng vừa có 2 văn bản gửi Bộ Văn hóa Th...
# 1    Chủ trì Hội nghị Thực trạng cung ứng con giống...
# 2    Để thực hiện hiệu quả mục tiêu của Chiến lược ...
# 3    Hội thảo là một trong những hoạt động nằm Tron...
# 4    Ngày 05 12 tại Hà Nội Cục Biển và Hải đảo Việt...
# ..                                                 ...
# 949  Trong một năm nóng nhất lịch sử đương đại băng...
# 950  Trong tuyên bố chung các ngân hàng phát triển ...
# 951  Trưa 2 12 giờ địa phương Thủ tướng Phạm Minh C...
# 952  Trước khi vào bài phát biểu của mình Thủ tướng...
# 953  Việt Nam và Đan Mạch sẽ tiếp tục hợp tác để đạ...
#
# [954 rows x 11 columns]

# %% [markdown]
# # Fetch Data from URL Link

# %% [markdown]
# ## process text

# %%
import re
def preprocess_text(text):
    # Loại bỏ khoảng trắng dư thừa và kí tự không mong muốn
    text = text.strip()  # Loại bỏ khoảng trắng ở đầu và cuối chuỗi
    text = re.sub(r'\s+', '.', text)  # Loại bỏ khoảng trắng dư thừa
    text = re.sub(r'[^\w\s]', ' ', text)  # Loại bỏ các kí tự không phải là chữ cái hoặc số
    # Thực hiện chuẩn hóa khoảng trắng giữa các từ
    words = text.split()
    text = ' '.join(words)
    return text

# %% [markdown]
# ## Get Title

# %%
def get_title(url):
  def get_soup(response):
    return BeautifulSoup(response.content, 'html.parser', from_encoding='utf-8')

  def get_h1_title(url):
      response = requests.get(url)
      if response.status_code == 200:
          soup = get_soup(response)
          title = soup.find('h1', class_=re.compile('title', re.IGNORECASE))
          if title:
              return title.get_text().strip()

          title = soup.find(attrs={"data-role": "title"})
          if title:
              return title.get_text().strip()

          title = soup.find('div', class_=re.compile('title', re.IGNORECASE))
          if title:
              return title.get_text().strip()
      return None

  return get_h1_title(url)

# %% [markdown]
# ## Get Description

# %%
def get_description_from_meta(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')

        description_tag = soup.find('meta', attrs={'name': 'description'})
        if description_tag:
            description = description_tag.get('content', '')
            if description:
                return description

        # Nếu không tìm thấy từ thẻ <meta name="description">, thử tìm từ thẻ <meta property="og:description">
        og_description_tag = soup.find('meta', property='og:description')
        if og_description_tag:
            og_description = og_description_tag.get('content', '')
            if og_description:
                return og_description

    return None

# %%
def get_description(url):
    try:
        # Fetch the webpage
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for 4xx/5xx status codes

        # Parse HTML content
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find meta tag with name="description"
        meta_tag = soup.find('meta', attrs={'name': 'description'})

        if meta_tag:
            # Extract content attribute
            description = meta_tag.get('content')
            return description
        else:
            # If name="description" not found, try og:description
            og_description_tag = soup.find('meta', attrs={'property': 'og:description'})
            if og_description_tag:
                og_description = og_description_tag.get('content')
                return og_description
            else:
                return "Description meta tag not found."

    except Exception as e:
        return f"An error occurred: {str(e)}"

# %% [markdown]
# ## Get paragraph from Different URL

# %%
def get_paragraphs(url):
  def get_soup(response):
    # Sử dụng mã hóa UTF-8 khi parse nội dung HTML
    return BeautifulSoup(response.content, 'html.parser', from_encoding='utf-8')

  def get_itemprop_articleBody(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = get_soup(response)
        article_body_div = soup.find('div', itemprop='articleBody')
        if article_body_div:
            paragraphs = article_body_div.find_all('p')
            if paragraphs:
                return '\n'.join([p.get_text() for p in paragraphs])
    return None

  def get_itemprop_articleBody_article(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = get_soup(response)
        article_body_div = soup.find('article', itemprop='articleBody')
        if article_body_div:
            paragraphs = article_body_div.find_all('p')
            if paragraphs:
                return '\n'.join([p.get_text() for p in paragraphs])
    return None
  def get_div_class(url, class_name):
      response = requests.get(url)
      if response.status_code == 200:
          soup = get_soup(response)
          main_div = soup.find('div', class_= class_name)
          if main_div:
              paragraphs = main_div.find_all('p')
              if paragraphs:
                  return '\n'.join([p.get_text() for p in paragraphs])
      return None

  def get_div_id(url, id_name):
    response = requests.get(url)
    if response.status_code == 200:
        soup = get_soup(response)
        specific_div = soup.find('div', id=id_name)
        if specific_div:
            paragraphs = specific_div.find_all('p')
            if paragraphs:
                return '\n'.join([p.get_text() for p in paragraphs])
    return None

  def get_article_id(url, id_name):
    response = requests.get(url)
    if response.status_code == 200:
        soup = get_soup(response)
        specific_article = soup.find('article', id=id_name)
        if specific_article:
            paragraphs = specific_article.find_all('p')
            if paragraphs:
                return '\n'.join([p.get_text() for p in paragraphs])
    return None

  def get_article_class(url, class_name):
      response = requests.get(url)
      if response.status_code == 200:
          soup = get_soup(response)
          specific_article = soup.find('article', class_= class_name)
          if specific_article:
              paragraphs = specific_article.find_all('p')
              if paragraphs:
                  return '\n'.join([p.get_text() for p in paragraphs])
      return None

  # 1
  if url.__contains__('laodong.vn'):
    return get_itemprop_articleBody(url)
  # 2
  elif url.__contains__('www.vietnamplus.vn'):
    return get_itemprop_articleBody(url)
  # 3
  elif url.__contains__('tienphong.vn'):
    return get_itemprop_articleBody(url)
  # 4
  elif url.__contains__('tuoitre.vn'):
    return get_itemprop_articleBody(url)
  # 5
  elif url.__contains__('baoxaydung.com.vn'):
    return get_div_class(url, 'item-content')
  # 6
  elif url.__contains__('plo.vn'):
    return get_itemprop_articleBody(url)
  # 7
  elif url.__contains__('dantri.com.vn'):
    return get_div_class(url, 'singular-content')
  # 8
  elif url.__contains__('thanhnien.vn'):
    return get_itemprop_articleBody(url)
  # 9 ####################Hiện đang k có quyền truy xuất ############################
  elif url.__contains__('baotintuc.vn'):
    return get_itemprop_articleBody(url)
   ####################Hiện đang k có quyền truy xuất ------------------------
  # 10
  elif url.__contains__('daibieunhandan.vn'):
    return get_div_class(url, 'detail-content-body')
  # 11
  elif url.__contains__('vov.vn'):
    return get_itemprop_articleBody_article(url)
  # 12
  elif url.__contains__('vtv.vn'):
    return get_div_id(url, 'entry-body')
  # 13
  elif url.__contains__('www.sggp.org.vn'):
    return get_itemprop_articleBody(url)
  # 14
  elif url.__contains__('kinhtedothi.vn'):
    return get_itemprop_articleBody(url)
  # 15
  elif url.__contains__('daidoanket.vn'):
    return get_div_class(url, 'b-maincontent')
  # 16
  elif url.__contains__('baotainguyenmoitruong.vn'):
    return get_div_class(url, 'entry') # entry
  # 17
  elif url.__contains__('nld.com.vn'):
    return get_itemprop_articleBody(url)
  # 18
  elif url.__contains__('www.moitruongvadothi.vn'):
    return get_article_id(url, "main-detail")
  # 19
  elif url.__contains__('baochinhphu.vn'):
    return get_div_class(url, 'main')
  # 20
  elif url.__contains__('hanoimoi.vn'):
    return get_div_class(url, 'entry')
  # 21
  elif url.__contains__('baodautu.vn'):
    return get_div_id(url, 'content_detail_news')
  # 22 ###### ĐANG LỖI HIỂN THỊ UNIKEY cho chữ -------------------------------
  elif url.__contains__('vietnamnet.vn'):
    return get_div_id(url, 'maincontent')
  # 23
  elif url.__contains__('congthuong.vn'):
    return get_itemprop_articleBody(url)
  # 24
  elif url.__contains__('danviet.vn'):
    return get_div_class(url, 'entry-body')
  # 25
  elif url.__contains__('thanhtra.com.vn'):
    return get_itemprop_articleBody(url)
  # 26
  elif url.__contains__('vnexpress.net'):
    return get_article_class(url, 'fck_detail')
  # 27
  elif url.__contains__('nhandan.vn'):
    return get_itemprop_articleBody(url)
  # 28
  elif url.__contains__('www.baogiaothong.vn'):
    return get_itemprop_articleBody(url)
  # 29
  elif url.__contains__('baophapluat.vn'):
    return get_itemprop_articleBody(url)
  # 30
  elif url.__contains__('congly.vn'):
    return get_div_class(url, 'entry')
  # 31
  elif url.__contains__('vneconomy.vn'):
    return get_div_class(url, 'detail__content')
  # 32
  elif url.__contains__('www.nguoiduatin.vn'):
    return get_article_class(url, 'article-content')
  # 33
  elif url.__contains__('www.congluan.vn'):
    return get_div_class(url, 'content-detail')
  # 34
  elif url.__contains__('diendandoanhnghiep.vn'):
    return get_article_id(url, 'detail-content')
  # 35
  elif url.__contains__('vtc.vn'):
    return get_itemprop_articleBody(url)
  # 36
  elif url.__contains__('1thegioi.vn'):
    return get_div_class(url, 'c-news-detail')


  # 37 ##### đang lỗi k nhận đc response: https://nongnghiep.vn/vu-can-bo-lua-dan-ban-dat-ai-lam-sai-thi-bo-tien-ra-ma-den-d369867.html
  elif url.__contains__('nongnghiep.vn'):
    # return get_itemprop_articleBody(url)
    return get_div_class(url, 'content')
  # 38
  elif url.__contains__('www.qdnd.vn'):
    return get_itemprop_articleBody(url)
 # 39
  elif url.__contains__('kinhtenongthon.vn'):
    return get_div_class(url, 'detainew')
  # 40
  elif url.__contains__('reatimes.vn'):
    return get_itemprop_articleBody(url)
  # 41
  elif url.__contains__('cand.com.vn'):
    return get_div_class(url,'detail-content-body')
  # 42
  elif url.__contains__('giaoducthoidai.vn'):
    return get_itemprop_articleBody(url)
  # 43
  elif url.__contains__('suckhoedoisong.vn'):
    return get_itemprop_articleBody(url)
  # 44
  elif url.__contains__('baoquangnam.vn'):
    return get_div_class(url, 'entry')
  # 45  # không thể crawl data ở web này, chắc là có bảo mật riêng ngăn chặn truy cập bằng tool
  elif url.__contains__('quochoi__.vn'):
    return get_itemprop_articleBody(url)
  # 46
  elif url.__contains__('thesaigontimes.vn'):
    return get_div_class(url, 'td-post-content')
  # 47
  elif url.__contains__('vnmedia.vn'):
    return get_div_class(url, 'td-post-content')
  # 48
  elif url.__contains__('www.phunuonline.com.vn'):
    return get_div_id(url, 'newscontents')
  # 49
  elif url.__contains__('www.quochoitv.vn'):
    return get_div_class(url, 'uk-article')

  # stop here
  else:
    return get_itemprop_articleBody(url)

# %% [markdown]
# # Processing Article

# %%
import csv

# Set a limit for the number of records to process at a time
batch_limit = 100

# Count the number of records processed
records_processed = 0

# Iterate through each link in the 'Link_tai_bai' column and fetch article text
for index, link_tin_bai in enumerate(df_cleaned['Link_tin_bai']):
    print(f"Processing article {index + 1}/{len(df_cleaned)}")

    description_from_meta = ""
    paragraph = ""
    title = ""

    try:
        title = get_title(link_tin_bai)
        title = preprocess_text(title)
        df_cleaned.at[index, 'Tieu_de'] = title

    except:
        title = ""
        print("No title in link: " + link_tin_bai)


    try:
        description = get_description(link_tin_bai)
        description = preprocess_text(description)
        df_cleaned.at[index, 'Description'] = description

    except:
        description = ""
        print("No description in link: " + link_tin_bai)


    # try:
    #     paragraph = get_paragraphs(link_tin_bai)
    #     paragraph = preprocess_text(paragraph)
    #     df_cleaned.at[index, 'Noi_dung_tin_bai'] = paragraph

    # except:
    #     paragraph = ""
    #     print("No paragraph in link: " + link_tin_bai)



    # Increment the count of records processed
    records_processed += 1

    # Check if the batch limit is reached
    if records_processed % batch_limit == 0:
        name_csv =  f"TNMT_{records_processed}.csv"
        df_cleaned.to_csv(name_csv, index=False, encoding='utf-8')
        df_cleaned.to_excel(f"TNMT_{records_processed}.xlsx", index = False)

        print(f"{name_csv} has been created.")

# Save the DataFrame to a new CSV file
df_cleaned.to_csv(name_csv, index=False, encoding='utf-8')
df_cleaned.to_excel(f"TNMT_full.xlsx", index = False)
# Out:
# Processing article 1/954
# Processing article 2/954
# Processing article 3/954
# Processing article 4/954
# Processing article 5/954
# Processing article 6/954
# Processing article 7/954
# Processing article 8/954
# Processing article 9/954
# Processing article 10/954
# Processing article 11/954
# Processing article 12/954
# Processing article 13/954
# Processing article 14/954
# Processing article 15/954
# Processing article 16/954
# Processing article 17/954
# Processing article 18/954
# Processing article 19/954
# Processing article 20/954
# Processing article 21/954
# Processing article 22/954
# Processing article 23/954
# Processing article 24/954
# Processing article 25/954
# Processing article 26/954
# Processing article 27/954
# Processing article 28/954
# Processing article 29/954
# Processing article 30/954
# Processing article 31/954
# Processing article 32/954
# Processing article 33/954
# Processing article 34/954
# Processing article 35/954
# Processing article 36/954
# Processing article 37/954
# Processing article 38/954
# Processing article 39/954
# Processing article 40/954
# Processing article 41/954
# Processing article 42/954
# Processing article 43/954
# Processing article 44/954
# Processing article 45/954
# Processing article 46/954
# Processing article 47/954
# No title in link: https://thanhnien.vn/159-doanh-nghiep-o-da-nang-se-duoc-mien-giam-30-tien-thue-dat-nam-2023-185231213174441436.htm
# Processing article 48/954
# Processing article 49/954
# Processing article 50/954
# Processing article 51/954
# Processing article 52/954
# Processing article 53/954
# Processing article 54/954
# Processing article 55/954
# Processing article 56/954
# Processing article 57/954
# Processing article 58/954
# Processing article 59/954
# Processing article 60/954
# Processing article 61/954
# Processing article 62/954
# Processing article 63/954
# Processing article 64/954
# Processing article 65/954
# Processing article 66/954
# Processing article 67/954
# Processing article 68/954
# Processing article 69/954
# Processing article 70/954
# Processing article 71/954
# Processing article 72/954
# Processing article 73/954
# Processing article 74/954
# Processing article 75/954
# Processing article 76/954
# Processing article 77/954
# Processing article 78/954
# Processing article 79/954
# Processing article 80/954
# Processing article 81/954
# Processing article 82/954
# Processing article 83/954
# Processing article 84/954
# Processing article 85/954
# Processing article 86/954
# Processing article 87/954
# Processing article 88/954
# Processing article 89/954
# Processing article 90/954
# Processing article 91/954
# Processing article 92/954
# Processing article 93/954
# Processing article 94/954
# Processing article 95/954
# Processing article 96/954
# Processing article 97/954
# Processing article 98/954
# Processing article 99/954
# Processing article 100/954
# TNMT_100.csv has been created.
# Processing article 101/954
# Processing article 102/954
# Processing article 103/954
# Processing article 104/954
# Processing article 105/954
# Processing article 106/954
# Processing article 107/954
# Processing article 108/954
# Processing article 109/954
# Processing article 110/954
# Processing article 111/954
# Processing article 112/954
# Processing article 113/954
# Processing article 114/954
# Processing article 115/954
# Processing article 116/954
# Processing article 117/954
# Processing article 118/954
# Processing article 119/954
# Processing article 120/954
# Processing article 121/954
# Processing article 122/954
# Processing article 123/954
# Processing article 124/954
# Processing article 125/954
# Processing article 126/954
# Processing article 127/954
# Processing article 128/954
# Processing article 129/954
# Processing article 130/954
# Processing article 131/954
# Processing article 132/954
# Processing article 133/954
# Processing article 134/954
# Processing article 135/954
# Processing article 136/954
# Processing article 137/954
# Processing article 138/954
# Processing article 139/954
# Processing article 140/954
# Processing article 141/954
# Processing article 142/954
# Processing article 143/954
# Processing article 144/954
# Processing article 145/954
# Processing article 146/954
# Processing article 147/954
# Processing article 148/954
# Processing article 149/954
# Processing article 150/954
# Processing article 151/954
# Processing article 152/954
# Processing article 153/954
# Processing article 154/954
# Processing article 155/954
# Processing article 156/954
# Processing article 157/954
# Processing article 158/954
# Processing article 159/954
# Processing article 160/954
# Processing article 161/954
# Processing article 162/954
# Processing article 163/954
# Processing article 164/954
# Processing article 165/954
# Processing article 166/954
# Processing article 167/954
# Processing article 168/954
# Processing article 169/954
# Processing article 170/954
# Processing article 171/954
# Processing article 172/954
# Processing article 173/954
# Processing article 174/954
# Processing article 175/954
# Processing article 176/954
# Processing article 177/954
# Processing article 178/954
# Processing article 179/954
# Processing article 180/954
# Processing article 181/954
# Processing article 182/954
# Processing article 183/954
# Processing article 184/954
# Processing article 185/954
# Processing article 186/954
# Processing article 187/954
# Processing article 188/954
# Processing article 189/954
# Processing article 190/954
# Processing article 191/954
# Processing article 192/954
# Processing article 193/954
# Processing article 194/954
# Processing article 195/954
# Processing article 196/954
# Processing article 197/954
# Processing article 198/954
# Processing article 199/954
# Processing article 200/954
# TNMT_200.csv has been created.
# Processing article 201/954
# Processing article 202/954
# Processing article 203/954
# Processing article 204/954
# Processing article 205/954
# Processing article 206/954
# Processing article 207/954
# Processing article 208/954
# Processing article 209/954
# Processing article 210/954
# Processing article 211/954
# Processing article 212/954
# Processing article 213/954
# Processing article 214/954
# Processing article 215/954
# Processing article 216/954
# Processing article 217/954
# Processing article 218/954
# Processing article 219/954
# Processing article 220/954
# Processing article 221/954
# Processing article 222/954
# Processing article 223/954
# Processing article 224/954
# Processing article 225/954
# Processing article 226/954
# Processing article 227/954
# Processing article 228/954
# Processing article 229/954
# Processing article 230/954
# Processing article 231/954
# Processing article 232/954
# Processing article 233/954
# Processing article 234/954
# Processing article 235/954
# Processing article 236/954
# Processing article 237/954
# Processing article 238/954
# Processing article 239/954
# Processing article 240/954
# Processing article 241/954
# Processing article 242/954
# Processing article 243/954
# Processing article 244/954
# Processing article 245/954
# Processing article 246/954
# Processing article 247/954
# Processing article 248/954
# Processing article 249/954
# Processing article 250/954
# Processing article 251/954
# Processing article 252/954
# Processing article 253/954
# Processing article 254/954
# Processing article 255/954
# Processing article 256/954
# Processing article 257/954
# Processing article 258/954
# Processing article 259/954
# Processing article 260/954
# Processing article 261/954
# Processing article 262/954
# Processing article 263/954
# Processing article 264/954
# Processing article 265/954
# Processing article 266/954
# Processing article 267/954
# Processing article 268/954
# Processing article 269/954
# Processing article 270/954
# Processing article 271/954
# Processing article 272/954
# Processing article 273/954
# Processing article 274/954
# Processing article 275/954
# Processing article 276/954
# Processing article 277/954
# Processing article 278/954
# Processing article 279/954
# Processing article 280/954
# Processing article 281/954
# Processing article 282/954
# Processing article 283/954
# Processing article 284/954
# Processing article 285/954
# Processing article 286/954
# Processing article 287/954
# Processing article 288/954
# Processing article 289/954
# Processing article 290/954
# Processing article 291/954
# Processing article 292/954
# Processing article 293/954
# Processing article 294/954
# Processing article 295/954
# Processing article 296/954
# Processing article 297/954
# Processing article 298/954
# Processing article 299/954
# Processing article 300/954
# TNMT_300.csv has been created.
# Processing article 301/954
# Processing article 302/954
# Processing article 303/954
# Processing article 304/954
# Processing article 305/954
# Processing article 306/954
# Processing article 307/954
# Processing article 308/954
# Processing article 309/954
# Processing article 310/954
# Processing article 311/954
# Processing article 312/954
# Processing article 313/954
# Processing article 314/954
# Processing article 315/954
# Processing article 316/954
# Processing article 317/954
# Processing article 318/954
# Processing article 319/954
# Processing article 320/954
# Processing article 321/954
# Processing article 322/954
# Processing article 323/954
# Processing article 324/954
# Processing article 325/954
# Processing article 326/954
# Processing article 327/954
# Processing article 328/954
# Processing article 329/954
# Processing article 330/954
# Processing article 331/954
# No description in link: https://kinhtenongthon.vn/Gop-y-Du-thao-Luat-Dat-dai-sua-doi-Hai-y-kien-ve-quan-ly-su-dung-dat-trong-lua-post60272.html
# Processing article 332/954
# Processing article 333/954
# Processing article 334/954
# Processing article 335/954
# Processing article 336/954
# Processing article 337/954
# Processing article 338/954
# No description in link: https://kinhtenongthon.vn/Gop-y-Du-thao-Luat-Dat-dai-sua-doi-Vai-y-kien-ve-quan-ly-su-dung-dat-nong-nghiep-post60128.html
# Processing article 339/954
# Processing article 340/954
# Processing article 341/954
# Processing article 342/954
# Processing article 343/954
# Processing article 344/954
# Processing article 345/954
# Processing article 346/954
# Processing article 347/954
# Processing article 348/954
# Processing article 349/954
# Processing article 350/954
# Processing article 351/954
# Processing article 352/954
# Processing article 353/954
# Processing article 354/954
# Processing article 355/954
# Processing article 356/954
# Processing article 357/954
# Processing article 358/954
# Processing article 359/954
# Processing article 360/954
# Processing article 361/954
# Processing article 362/954
# Processing article 363/954
# Processing article 364/954
# Processing article 365/954
# Processing article 366/954
# Processing article 367/954
# Processing article 368/954
# Processing article 369/954
# Processing article 370/954
# Processing article 371/954
# Processing article 372/954
# Processing article 373/954
# Processing article 374/954
# Processing article 375/954
# Processing article 376/954
# Processing article 377/954
# Processing article 378/954
# Processing article 379/954
# Processing article 380/954
# Processing article 381/954
# Processing article 382/954
# Processing article 383/954
# Processing article 384/954
# Processing article 385/954
# Processing article 386/954
# Processing article 387/954
# Processing article 388/954
# Processing article 389/954
# Processing article 390/954
# Processing article 391/954
# Processing article 392/954
# Processing article 393/954
# Processing article 394/954
# Processing article 395/954
# Processing article 396/954
# Processing article 397/954
# Processing article 398/954
# Processing article 399/954
# Processing article 400/954
# TNMT_400.csv has been created.
# Processing article 401/954
# Processing article 402/954
# Processing article 403/954
# Processing article 404/954
# Processing article 405/954
# Processing article 406/954
# Processing article 407/954
# Processing article 408/954
# Processing article 409/954
# Processing article 410/954
# Processing article 411/954
# Processing article 412/954
# Processing article 413/954
# Processing article 414/954
# Processing article 415/954
# Processing article 416/954
# Processing article 417/954
# Processing article 418/954
# Processing article 419/954
# Processing article 420/954
# Processing article 421/954
# Processing article 422/954
# Processing article 423/954
# Processing article 424/954
# Processing article 425/954
# Processing article 426/954
# Processing article 427/954
# Processing article 428/954
# Processing article 429/954
# Processing article 430/954
# Processing article 431/954
# Processing article 432/954
# Processing article 433/954
# Processing article 434/954
# Processing article 435/954
# Processing article 436/954
# Processing article 437/954
# Processing article 438/954
# Processing article 439/954
# Processing article 440/954
# Processing article 441/954
# Processing article 442/954
# Processing article 443/954
# Processing article 444/954
# Processing article 445/954
# Processing article 446/954
# Processing article 447/954
# Processing article 448/954
# Processing article 449/954
# Processing article 450/954
# Processing article 451/954
# Processing article 452/954
# Processing article 453/954
# Processing article 454/954
# Processing article 455/954
# Processing article 456/954
# Processing article 457/954
# Processing article 458/954
# Processing article 459/954
# Processing article 460/954
# Processing article 461/954
# Processing article 462/954
# Processing article 463/954
# Processing article 464/954
# Processing article 465/954
# Processing article 466/954
# Processing article 467/954
# Processing article 468/954
# Processing article 469/954
# Processing article 470/954
# Processing article 471/954
# Processing article 472/954
# Processing article 473/954
# Processing article 474/954
# Processing article 475/954
# Processing article 476/954
# Processing article 477/954
# Processing article 478/954
# Processing article 479/954
# Processing article 480/954
# Processing article 481/954
# Processing article 482/954
# Processing article 483/954
# Processing article 484/954
# Processing article 485/954
# Processing article 486/954
# Processing article 487/954
# Processing article 488/954
# Processing article 489/954
# Processing article 490/954
# Processing article 491/954
# Processing article 492/954
# Processing article 493/954
# Processing article 494/954
# Processing article 495/954
# Processing article 496/954
# Processing article 497/954
# Processing article 498/954
# Processing article 499/954
# Processing article 500/954
# TNMT_500.csv has been created.
# Processing article 501/954
# Processing article 502/954
# Processing article 503/954
# Processing article 504/954
# Processing article 505/954
# Processing article 506/954
# Processing article 507/954
# Processing article 508/954
# Processing article 509/954
# Processing article 510/954
# Processing article 511/954
# Processing article 512/954
# Processing article 513/954
# Processing article 514/954
# Processing article 515/954
# Processing article 516/954
# Processing article 517/954
# Processing article 518/954
# Processing article 519/954
# Processing article 520/954
# Processing article 521/954
# Processing article 522/954
# Processing article 523/954
# Processing article 524/954
# Processing article 525/954
# Processing article 526/954
# Processing article 527/954
# Processing article 528/954
# Processing article 529/954
# Processing article 530/954
# Processing article 531/954
# Processing article 532/954
# Processing article 533/954
# Processing article 534/954
# Processing article 535/954
# Processing article 536/954
# Processing article 537/954
# Processing article 538/954
# Processing article 539/954
# Processing article 540/954
# Processing article 541/954
# Processing article 542/954
# Processing article 543/954
# Processing article 544/954
# Processing article 545/954
# Processing article 546/954
# Processing article 547/954
# Processing article 548/954
# Processing article 549/954
# Processing article 550/954
# Processing article 551/954
# Processing article 552/954
# Processing article 553/954
# Processing article 554/954
# Processing article 555/954
# Processing article 556/954
# Processing article 557/954
# Processing article 558/954
# Processing article 559/954
# Processing article 560/954
# Processing article 561/954
# Processing article 562/954
# Processing article 563/954
# Processing article 564/954
# Processing article 565/954
# Processing article 566/954
# Processing article 567/954
# Processing article 568/954
# Processing article 569/954
# Processing article 570/954
# Processing article 571/954
# Processing article 572/954
# Processing article 573/954
# Processing article 574/954
# Processing article 575/954
# Processing article 576/954
# Processing article 577/954
# Processing article 578/954
# Processing article 579/954
# Processing article 580/954
# Processing article 581/954
# Processing article 582/954
# Processing article 583/954
# Processing article 584/954
# Processing article 585/954
# Processing article 586/954
# Processing article 587/954
# Processing article 588/954
# Processing article 589/954
# Processing article 590/954
# Processing article 591/954
# Processing article 592/954
# No description in link: https://kinhtenongthon.vn/Thu-tuong-Mot-Chau-A-phat-thai-rong-bang-0-se-tro-thanh-hien-thuc-post60179.html
# Processing article 593/954
# Processing article 594/954
# Processing article 595/954
# Processing article 596/954
# Processing article 597/954
# Processing article 598/954
# Processing article 599/954
# Processing article 600/954
# TNMT_600.csv has been created.
# Processing article 601/954
# Processing article 602/954
# Processing article 603/954
# Processing article 604/954
# Processing article 605/954
# Processing article 606/954
# Processing article 607/954
# Processing article 608/954
# Processing article 609/954
# Processing article 610/954
# Processing article 611/954
# Processing article 612/954
# Processing article 613/954
# Processing article 614/954
# Processing article 615/954
# Processing article 616/954
# Processing article 617/954
# Processing article 618/954
# Processing article 619/954
# Processing article 620/954
# Processing article 621/954
# Processing article 622/954
# Processing article 623/954
# Processing article 624/954
# Processing article 625/954
# Processing article 626/954
# Processing article 627/954
# Processing article 628/954
# Processing article 629/954
# Processing article 630/954
# No description in link: https://kinhtenongthon.vn/Tai-su-dung-chat-thai-chan-nuoi-khac-phuc-o-nhiem-moi-truong-post60220.html
# Processing article 631/954
# Processing article 632/954
# Processing article 633/954
# Processing article 634/954
# Processing article 635/954
# Processing article 636/954
# Processing article 637/954
# Processing article 638/954
# Processing article 639/954
# Processing article 640/954
# Processing article 641/954
# Processing article 642/954
# Processing article 643/954
# Processing article 644/954
# Processing article 645/954
# Processing article 646/954
# Processing article 647/954
# Processing article 648/954
# Processing article 649/954
# Processing article 650/954
# Processing article 651/954
# Processing article 652/954
# Processing article 653/954
# Processing article 654/954
# Processing article 655/954
# Processing article 656/954
# Processing article 657/954
# Processing article 658/954
# Processing article 659/954
# Processing article 660/954
# Processing article 661/954
# Processing article 662/954
# Processing article 663/954
# Processing article 664/954
# Processing article 665/954
# Processing article 666/954
# Processing article 667/954
# Processing article 668/954
# Processing article 669/954
# Processing article 670/954
# Processing article 671/954
# Processing article 672/954
# Processing article 673/954
# Processing article 674/954
# Processing article 675/954
# Processing article 676/954
# Processing article 677/954
# Processing article 678/954
# Processing article 679/954
# Processing article 680/954
# Processing article 681/954
# Processing article 682/954
# Processing article 683/954
# Processing article 684/954
# Processing article 685/954
# No title in link: https://tuoitre.vn/khu-xu-ly-rac-thai-lon-nhat-dong-nai-muon-giam-50-khoi-luong-tiep-nhan-20231227175329311.htm
# Processing article 686/954
# Processing article 687/954
# Processing article 688/954
# Processing article 689/954
# Processing article 690/954
# Processing article 691/954
# Processing article 692/954
# Processing article 693/954
# Processing article 694/954
# Processing article 695/954
# Processing article 696/954
# Processing article 697/954
# Processing article 698/954
# Processing article 699/954
# Processing article 700/954
# TNMT_700.csv has been created.
# Processing article 701/954
# Processing article 702/954
# Processing article 703/954
# Processing article 704/954
# Processing article 705/954
# Processing article 706/954
# Processing article 707/954
# Processing article 708/954
# Processing article 709/954
# Processing article 710/954
# Processing article 711/954
# Processing article 712/954
# Processing article 713/954
# Processing article 714/954
# Processing article 715/954
# Processing article 716/954
# Processing article 717/954
# Processing article 718/954
# Processing article 719/954
# Processing article 720/954
# Processing article 721/954
# Processing article 722/954
# Processing article 723/954
# Processing article 724/954
# Processing article 725/954
# Processing article 726/954
# Processing article 727/954
# Processing article 728/954
# Processing article 729/954
# Processing article 730/954
# Processing article 731/954
# Processing article 732/954
# Processing article 733/954
# Processing article 734/954
# Processing article 735/954
# Processing article 736/954
# Processing article 737/954
# Processing article 738/954
# Processing article 739/954
# Processing article 740/954
# Processing article 741/954
# Processing article 742/954
# Processing article 743/954
# Processing article 744/954
# Processing article 745/954
# Processing article 746/954
# Processing article 747/954
# Processing article 748/954
# Processing article 749/954
# Processing article 750/954
# Processing article 751/954
# Processing article 752/954
# Processing article 753/954
# Processing article 754/954
# Processing article 755/954
# Processing article 756/954
# Processing article 757/954
# Processing article 758/954
# Processing article 759/954
# Processing article 760/954
# Processing article 761/954
# Processing article 762/954
# Processing article 763/954
# Processing article 764/954
# Processing article 765/954
# Processing article 766/954
# Processing article 767/954
# Processing article 768/954
# Processing article 769/954
# Processing article 770/954
# Processing article 771/954
# Processing article 772/954
# Processing article 773/954
# Processing article 774/954
# Processing article 775/954
# Processing article 776/954
# Processing article 777/954
# Processing article 778/954
# Processing article 779/954
# Processing article 780/954
# Processing article 781/954
# Processing article 782/954
# Processing article 783/954
# Processing article 784/954
# Processing article 785/954
# Processing article 786/954
# Processing article 787/954
# Processing article 788/954
# Processing article 789/954
# Processing article 790/954
# Processing article 791/954
# Processing article 792/954
# Processing article 793/954
# Processing article 794/954
# Processing article 795/954
# Processing article 796/954
# Processing article 797/954
# Processing article 798/954
# Processing article 799/954
# Processing article 800/954
# TNMT_800.csv has been created.
# Processing article 801/954
# Processing article 802/954
# Processing article 803/954
# Processing article 804/954
# Processing article 805/954
# Processing article 806/954
# Processing article 807/954
# Processing article 808/954
# Processing article 809/954
# Processing article 810/954
# Processing article 811/954
# Processing article 812/954
# Processing article 813/954
# Processing article 814/954
# Processing article 815/954
# Processing article 816/954
# Processing article 817/954
# Processing article 818/954
# Processing article 819/954
# Processing article 820/954
# Processing article 821/954
# Processing article 822/954
# Processing article 823/954
# Processing article 824/954
# Processing article 825/954
# Processing article 826/954
# No description in link: https://kinhtenongthon.vn/Ha-Giang-nang-cao-nhan-thuc-ve-moi-truong-vung-dong-bao-dan-toc-post60333.html
# Processing article 827/954
# Processing article 828/954
# Processing article 829/954
# Processing article 830/954
# Processing article 831/954
# Processing article 832/954
# Processing article 833/954
# Processing article 834/954
# Processing article 835/954
# Processing article 836/954
# Processing article 837/954
# Processing article 838/954
# Processing article 839/954
# Processing article 840/954
# Processing article 841/954
# Processing article 842/954
# Processing article 843/954
# Processing article 844/954
# Processing article 845/954
# Processing article 846/954
# Processing article 847/954
# Processing article 848/954
# Processing article 849/954
# Processing article 850/954
# Processing article 851/954
# Processing article 852/954
# Processing article 853/954
# Processing article 854/954
# Processing article 855/954
# Processing article 856/954
# Processing article 857/954
# Processing article 858/954
# Processing article 859/954
# Processing article 860/954
# Processing article 861/954
# Processing article 862/954
# Processing article 863/954
# Processing article 864/954
# Processing article 865/954
# Processing article 866/954
# Processing article 867/954
# Processing article 868/954
# Processing article 869/954
# Processing article 870/954
# Processing article 871/954
# Processing article 872/954
# Processing article 873/954
# Processing article 874/954
# Processing article 875/954
# Processing article 876/954
# Processing article 877/954
# Processing article 878/954
# Processing article 879/954
# Processing article 880/954
# Processing article 881/954
# Processing article 882/954
# Processing article 883/954
# Processing article 884/954
# No description in link: https://kinhtenongthon.vn/Quan-ly-chat-luong-moi-truong-nuoc-va-giai-phap-post60028.html
# Processing article 885/954
# Processing article 886/954
# Processing article 887/954
# Processing article 888/954
# Processing article 889/954
# Processing article 890/954
# Processing article 891/954
# Processing article 892/954
# Processing article 893/954
# Processing article 894/954
# Processing article 895/954
# Processing article 896/954
# Processing article 897/954
# Processing article 898/954
# Processing article 899/954
# Processing article 900/954
# TNMT_900.csv has been created.
# Processing article 901/954
# Processing article 902/954
# Processing article 903/954
# Processing article 904/954
# Processing article 905/954
# Processing article 906/954
# Processing article 907/954
# Processing article 908/954
# Processing article 909/954
# Processing article 910/954
# Processing article 911/954
# Processing article 912/954
# Processing article 913/954
# Processing article 914/954
# Processing article 915/954
# Processing article 916/954
# Processing article 917/954
# Processing article 918/954
# Processing article 919/954
# Processing article 920/954
# Processing article 921/954
# Processing article 922/954
# Processing article 923/954
# Processing article 924/954
# Processing article 925/954
# Processing article 926/954
# Processing article 927/954
# Processing article 928/954
# Processing article 929/954
# Processing article 930/954
# Processing article 931/954
# Processing article 932/954
# Processing article 933/954
# Processing article 934/954
# Processing article 935/954
# Processing article 936/954
# Processing article 937/954
# Processing article 938/954
# Processing article 939/954
# Processing article 940/954
# Processing article 941/954
# Processing article 942/954
# Processing article 943/954
# Processing article 944/954
# Processing article 945/954
# Processing article 946/954
# Processing article 947/954
# Processing article 948/954
# Processing article 949/954
# Processing article 950/954
# Processing article 951/954
# Processing article 952/954
# Processing article 953/954
# Processing article 954/954
